# %% [markdown]
# <a href="https://colab.research.google.com/github/IofchuSasha/Practicheskie/blob/02%2F04/%D0%9B%D0%B0%D0%B13!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторная3 Иофчу А.С.

# %% [markdown]
# ![йцукапенр.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![апро.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
def f2(x):
  return np.exp(-x)
integrate.quad(f2, 0.0, np.inf)
# Out:
# (1.0000000000000002, 5.842606742906004e-11)

# %%
from scipy import integrate
def f(x):
     return x/(x**4+3*x**2+2)
integrate.quad(f, -5.0, 5.0)
# Out:
# (0.0, 6.6956702224674734e-15)

# %%
import math

def integral(x1,x2):
  return (math.log1p(x1+1)-math.log1p(x1+2)-(math.log1p(x1+1)-math.log1p(x1+2)))*(1/2)
integral(5,-5)
# Out:
# 0.0

# %% [markdown]
# ![йцу.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
def af(y, x):
  return x-y

# %%
x = np.linspace(-1,1,100)
y0 = 1
y = odeint(af ,y0 , x)
y = np.array(y).flatten()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.plot(x,y)
